# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
data = pd.read_csv('Churn_Modelling.csv')
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
def count(x, fig):
    plt.subplot(6, 3, fig)
    sns.countplot(x=x, data=data, hue='Exited')

plt.figure(figsize=(15,30))

count('Geography',1)
count('Gender',2)
count('IsActiveMember',3)
count('HasCrCard',4)
count('Tenure',5)
count('NumOfProducts',6)

# %%
def count(x,num_bins, fig):
    plt.subplot(6,2,fig)
    sns.countplot(x=(pd.cut(data[x], bins=num_bins)),data=data,hue='Exited')

plt.figure(figsize=(15,30))

count('Age',5,1)
count('Balance',3,2)
count('EstimatedSalary',4,3)

# %%
for i in data[['Age','Balance','EstimatedSalary','Tenure']]:
    fig, axes = plt.subplots(1, 2, figsize = (18,5))
    sns.histplot(data[i], ax=axes[0])
    sns.boxplot(data[i], ax=axes[1], orient='h')
    plt.show()

# %%
df=data.iloc[:,3:]
df=pd.concat([df,pd.get_dummies(df['Geography'])],axis=1)
df=df.drop(columns=['Geography'])
df=pd.concat([df,pd.get_dummies(df['Gender'])],axis=1)
df=df.drop(columns=['Gender'])
df=df.rename(columns = {'Male':'Gender'})
df=df.drop(columns=['Female'])

# %%
corr = 100 * df.corr()
sns.heatmap(corr, annot=True, fmt='.1f')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

cols_to_scale = ['Tenure','EstimatedSalary','NumOfProducts','Age','Balance','CreditScore']

df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
X=df.drop(columns=['Exited'])
y=df.Exited

# %%
X.shape,y.shape
# Out:
# ((10000, 12), (10000,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

X_train.shape, X_test.shape
# Out:
# ((8000, 12), (2000, 12))

# %%
model = keras.Sequential([
    keras.layers.Dense(23, activation='relu', input_shape=(12,)),
    keras.layers.Dense(18, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 250/250 [==============================] - 1s 1ms/step - loss: 0.4778 - accuracy: 0.7865
# Epoch 2/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8159
# Epoch 3/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8351
# Epoch 4/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3689 - accuracy: 0.8471
# Epoch 5/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8544
# Epoch 6/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3514 - accuracy: 0.8570
# Epoch 7/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3471 - accuracy: 0.8572
# Epoch 8/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3451 - accuracy: 0.8577
# Epoch 9/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.8593
# Epoch 10/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3407 - accuracy: 0.8581
# Epoch 11/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3397 - accuracy: 0.8590
# Epoch 12/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3378 - accuracy: 0.8606
# Epoch 13/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3366 - accuracy: 0.8643
# Epoch 14/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3352 - accuracy: 0.8606
# Epoch 15/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3339 - accuracy: 0.8626
# Epoch 16/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8621
# Epoch 17/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8629
# Epoch 18/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3312 - accuracy: 0.8629
# Epoch 19/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8633
# Epoch 20/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8625
# Epoch 21/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3289 - accuracy: 0.8670
# Epoch 22/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8654
# Epoch 23/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3268 - accuracy: 0.8639
# Epoch 24/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3266 - accuracy: 0.8631
# Epoch 25/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3256 - accuracy: 0.8655
# Epoch 26/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3259 - accuracy: 0.8635
# Epoch 27/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3250 - accuracy: 0.8650
# Epoch 28/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3248 - accuracy: 0.8651
# Epoch 29/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3246 - accuracy: 0.8676
# Epoch 30/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3236 - accuracy: 0.8649
# Epoch 31/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3227 - accuracy: 0.8666
# Epoch 32/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3225 - accuracy: 0.8674
# Epoch 33/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3220 - accuracy: 0.8674
# Epoch 34/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3213 - accuracy: 0.8654
# Epoch 35/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3217 - accuracy: 0.8661
# Epoch 36/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3196 - accuracy: 0.8654
# Epoch 37/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3200 - accuracy: 0.8666
# Epoch 38/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3191 - accuracy: 0.8681
# Epoch 39/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3189 - accuracy: 0.8677
# Epoch 40/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3188 - accuracy: 0.8655
# Epoch 41/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3180 - accuracy: 0.8689
# Epoch 42/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3174 - accuracy: 0.8691
# Epoch 43/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3172 - accuracy: 0.8675
# Epoch 44/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3166 - accuracy: 0.8687
# Epoch 45/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3162 - accuracy: 0.8677
# Epoch 46/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3168 - accuracy: 0.8690
# Epoch 47/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.8683
# Epoch 48/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3154 - accuracy: 0.8700
# Epoch 49/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3152 - accuracy: 0.8695
# Epoch 50/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3141 - accuracy: 0.8715

# %%
y_pred = model.predict(X_test)
y_pred_binary = (y_pred >= 0.5).astype(int)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
recall = recall_score(y_test, y_pred_binary)
f1 = f1_score(y_test, y_pred_binary)
roc_auc = roc_auc_score(y_test, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# 63/63 [==============================] - 0s 1ms/step
# Accuracy: 0.861
# Precision: 0.725925925925926
# Recall: 0.49
# F1 Score: 0.5850746268656717
# ROC AUC: 0.721875

# %%
cm = confusion_matrix(y_test, y_pred_binary)
sns.heatmap(cm, annot=True, fmt='d')
plt.ylabel("Predicted Labels")
plt.xlabel("True Labels")
plt.show()
